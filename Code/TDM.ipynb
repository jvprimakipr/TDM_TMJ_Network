# %%
from Functions.class_TM import TM
from Functions.class_characters import characters

c = characters()

# %%
pages1 = []
pages2 = []
pages3 = []
pages4 = []
pages5 = []
pages6 = []
pages7 = []
pages8 = []
pages9 = []
pages10 = []
pages11 = []
pages12 = []
pages13 = []
pages14 = []
pages15 = []
pages16 = []
pages17 = []
pages18 = []
pages19 = []
pages20 = []
pages21 = []
pages22 = []
pages23 = []
pages24 = []
pages25 = []

# %%
c.atend(reset = True)
c.mot(reset = True)
c.fat(reset = True)
c.fig(reset = True)
c.child(reset = True)
c.comic_book = 'gibi 1'

# %%
pages1 = [[c.viv, c.mon, c.ceb, c.mag], # capa
          [c.viv, c.bor, c.mon, c.ceb, c.mag, c.san], # introdução
          [c.viv, c.bor], # gato = bóris
          [c.viv, c.bor, c.mon, c.mag, c.ceb, c.cas],
          [c.viv, c.bor],
          [c.viv, c.bor],
          [c.viv, c.bor, c.atend(), c.atend()],
          [c.viv, c.bor, c.atend(n = 1)],
          [c.viv, c.bor, c.atend(n = 1)],
          [c.viv, c.bor, c.ceb, c.cas],
          [c.viv, c.bor, c.mon, c.ceb, c.cas],
          [c.viv, c.bor, c.mon, c.ceb, c.cas],
          [c.viv, c.mon, c.ceb, c.cas],
          [c.viv, c.mon, c.ceb, c.cas],
          [c.viv, c.bor, c.mon, c.ceb, c.cas],
          [c.viv, c.bor, c.mag, c.child()],
          [c.viv, c.bor, c.mag],
          [c.viv, c.bor, c.mag, c.fig(), c.atend()],
          [c.viv, c.mag, c.atend()],
          [c.viv, c.mon, c.mag, c.ceb, c.cas, c.atend(n = 4)],
          [c.viv, c.mon, c.mag, c.ceb, c.cas],
          [c.viv, c.mon, c.mag, c.ceb, c.cas],
          [c.viv, c.mon, c.mag, c.ceb, c.cas], # dinossauros do horácio também?
          [c.viv, c.mag], # dinossauros do horácio também?
          [c.viv, c.bor, c.mag],
          [c.viv, c.bor, c.mon, c.mag, c.ceb, c.cas],
          [c.pit],
          [c.pit],
          [c.pit, 'Dinossauro verde'],
          [c.pit, 'Dinossauro verde'],
          [c.pen],
          [c.pen, 'Gato laranja'],
          [c.ceb, c.floq],
          [c.ceb, c.floq],
          [c.dud, c.mdud],
          [c.dud, 'Lactos Kid'], # caixinha de leite vilã
          [c.dud, 'Lactos Kid', 'Milhus', 'Ervilhus'], # lata de milho e ervilha vilãs
          [c.dud, 'Lactos Kid', 'Milhus', 'Ervilhus', 'Macarrônios', 'Povo Feijônico', 'Monstro Q.I. Jo'], # macarrão, feijões e queijo, todos vilões
          [c.dud, c.mdud, 'Lactos Kid', 'Milhus', 'Ervilhus', 'Povo Feijônico'],
          [c.bid, c.franj, c.ceb],
          [c.bid, c.ceb, c.mon, c.cas],
          [c.ast, 'Monstro Verde Grande', 'Monstro Rosa'],
          [c.ast, 'Monstro Rosa', 'Monstro Verde Pequeno'],
          [c.zlel, c.fig(), c.fig(), c.atend(), 'Galinha do Zé Lelé', 'Pintinho'],
          [c.zlel, 'Galinha do Zé Lelé', c.atend(n = 5), c.atend(), c.child(), c.child(), c.child(), c.child(), c.child(),
           c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child()],
          [c.zlel, 'Galinha do Zé Lelé', c.mlel, c.child(), c.child(), c.child(), c.child()],
          [c.lob, 'Cachorro 1', 'Cachorro 2', 'Peixe', 'Pássaro', 'Menino de cabelo laranja e camisa verde'],
          [c.lob, 'Cachorro 1', 'Cachorro 2', c.child(), c.fig()],
          [c.mon, c.franj, c.bid],
          [c.mon, c.mag, c.min, c.ceb, c.floq],
          [c.tin, c.pip],
          [c.tin, c.pip, c.ser],
          [c.tin, c.pip, c.ser],
          [c.tin, c.pip],
          [c.tin, c.pip, c.ser],
          [c.tin, c.pip, c.ser],
          [c.zvam, c.mum, c.pen, c.cra]] # última página (tirinha)

c.atend(reset = True)
c.mot(reset = True)
c.fat(reset = True)
c.fig(reset = True)
c.child(reset = True)
c.comic_book = 'gibi 2'

# %%
pages2 = [[c.mag, 'Dud Van Winkle', c.fig()], # capa (Dud parece o Dudu)
          [c.mag, c.dud],
          [c.mag, c.dud],
          [c.mag, c.dud],
          [c.mag, c.dud, c.fig()],
          ['Mulher - História', 'Homem - História', 'Boi 1', 'Boi 2', 'Cachorro', 'Galo',
           'Galinha', c.dud, 'Dud Van Winkle'],
          [c.mag, c.dud, 'Dud Van Winkle', 'Vovó - História'],
          ['Dud Van Winkle', 'Vaca', 'Galinha', 'Tartaruga', 'Caracol'],
          [c.mag, c.dud, 'Dud Van Winkle'],
          ['Dud Van Winkle'],
          [c.dud, c.mag, 'Construtor 1', 'Construtor 2', 'Construtor 3'],
          ['Construtor 4', 'Construtor 5', c.child(), c.mot()],
          [c.mau, 'Dud Van Winkle', c.fig()],
          [c.mau, 'Dud Van Winkle'],
          ['Dud Van Winkle', c.dud, c.mag],
          [c.dud, c.mag, c.pen], # penadinho era num brinquedo
          [c.dud, c.mag, c.mau, 'Dud Van Winkle'],
          [c.cas],
          [c.cas],
          [c.ceb, c.mon, c.mag, c.san],
          [c.cas, c.mon, c.mag, c.san],
          [c.mon, c.mag, c.san, c.xav],
          [c.moca, c.min],
          [c.mon, c.mag, c.san, c.moca, c.min, c.chov, c.floq, 'Cachorro Verde Aleatório'],
          [c.franj, c.bid, c.moca, c.min, c.chov, c.floq, 'Cachorro Verde Aleatório'],
          [c.lob, c.zvam],
          [c.zvam, c.pen, c.fra, c.mum],
          [c.mon, c.mag, c.mar, 'Vendedor de Picolé'],
          [c.mon, c.ceb, 'Titi', 'Super Homem', c.cas],
          [c.pit, 'Homem das Cavernas 1', 'Homem das Cavernas 2'],
          [c.pit, 'Homem das Cavernas 1', 'Homem das Cavernas 2'],
          [c.pit, 'Homem das Cavernas 1', 'Homem das Cavernas 2'],
          [c.pit, 'Dente de Sabre', 'Dinossauro Amarelo'],
          [c.pit, 'Homem das Cavernas 3', 'Homem das Cavernas 4'],
          [c.dud],
          [c.dud],
          [c.dud, c.mdud],
          [c.mag, c.franj],
          [c.mag, c.franj],
          [c.mag, c.franj],
          [c.franj],
          [c.mag, c.franj],
          [c.mag, c.franj],
          [c.mag, c.franj],
          [c.mag, c.mmag], # acho que ela quem chama a magali para casa (não aparece, só o balão de voz)
          [c.mag, 'Anjo da Guarda da Magali'],
          [c.bid, 'Pedra'], # a pedra fala!!!
          [c.bid, 'Pedra', c.manf],
          [c.bid, c.manf, 'Desenhista 1', 'Desenhista 2', 'Desenhista 3'],
          [c.bid, c.manf, 'Pedra'],
          [c.bid, 'Pedra', c.manf],
          [c.bid, c.manf, 'Pedra'],
          [c.bid, c.manf, 'Pedra'],
          [c.bid, c.manf, 'Pedra'],
          [c.bid, c.manf, 'Pedra'],
          [c.bid, c.manf, 'Desenhista 1', 'Desenhista 2', 'Desenhista 3'],
          [c.bid, c.manf, 'Desenhista 1', 'Desenhista 2', 'Desenhista 3', 'Pedra']]

c.atend(reset = True)
c.mot(reset = True)
c.fat(reset = True)
c.fig(reset = True)
c.child(reset = True)
c.comic_book = 'gibi 3'

# %%
pages3 = [[c.pceb, c.ceb, c.mon, c.cas], # capa
          [c.pceb, c.ceb], # introdução
          [c.ceb, c.pceb, c.atend(), c.atend(),
           c.child(), c.child(), c.child(), c.child()],
          [c.ceb, c.pceb, c.child(), c.child(), c.child(), c.fat()],
          [c.ceb, c.pceb, c.child(), c.child(), c.child(), c.mot(), c.atend()],
          [c.ceb, c.pceb, c.child(), c.child()],
          [c.ceb, c.pceb, c.child(n = 12)],
          [c.ceb, c.pceb, c.child(n = 12)],
          [c.ceb, c.pceb, c.atend()],
          [c.ceb, c.pceb, c.child()],
          [c.ceb, c.pceb, c.child(), c.child()],
          [c.ceb, c.pceb, c.child(n = 14), c.child(n = 15)],
          [c.ceb, c.pceb, c.child(), c.child(), c.child(), c.child(), c.child()],
          [c.ceb, c.pceb, c.child(), c.child(), c.child()],
          [c.ceb, c.pceb, c.mot(), 'Bebê', c.fat()],
          [c.ceb, c.pceb, 'Bebê', c.fat(n = 2)],
          [c.ceb, c.pceb, 'Jogador 1', 'Jogador 2', 'Jogador 3',
           'Jogador 4', 'Jogador 5', c.mceb, c.fat(n = 2), 'Bebê'],
          [c.ceb, c.pceb],
          [c.ceb, c.pceb, 'Pai Caramujo', 'Filho Caramujo'],
          [c.mon, c.san, c.mag],
          [c.ceb, c.mag, c.cas, c.xav, 'Sorveteiro'],
          [c.cas, c.fig(), c.fig(), c.fig()],
          [c.cas, c.fig(), c.fig(), c.fig(), c.fig()],
          [c.cas, c.mcas, 'Caixa do Supermercado'],
          [c.pit, c.var, 'Dinossauro Rosa'],
          [c.pit, c.var, c.bol],
          [c.pit, c.var, 'Homem Tigre 1'],
          ['Homem Tigre 1', c.pit, c.var, c.bol, 'Homem das Cavernas 1'],
          [c.pit, c.var, c.bol, 'Homem Tigre 1', 'Homem Tigre 2', 'Homem Tigre 3'],
          [c.pit, c.var, c.bol, 'Homem das Cavernas 2', 'Homem das Cavernas 3',
           'Homem das Cavernas 4', 'Homem das Cavernas 5', 'Homem das Cavernas 6'],
          ['Homem Tigre 1', 'Homem Tigre 2', 'Homem Tigre 3', 'Homem Tigre 4', 'Homem Tigre 5', c.pit,
           c.bol, c.var, 'Homem das Cavernas 1', 'Homem das Cavernas 2', 'Homem das Cavernas 3'],
          [c.zvam, c.fig()],
          [c.ceb, c.cas, c.con], # passatempo
          [c.ceb, c.mon, c.cas, c.mag, c.marceb, c.xav, c.bid], # correio
          [c.cas, c.ceb, c.mon, c.mag], # correio de novo
          [c.pen, c.fig(), c.fig(), c.fig()],
          [c.pen],
          [c.pen, c.fra],
          [c.pen, c.fra, c.zvam, c.mum, c.zcav],
          [c.pen, c.fra, c.zvam, c.mum, c.zcav, c.lob,
           c.mor, c.alm, 'Fantasma 1', 'Fantasma 2'],
          [c.mon, c.ceb, c.cas, c.san],
          [c.mon, c.ceb, c.cas, c.san],
          [c.pap, c.cai],
          [c.pap, c.cai, 'Onça'],
          [c.pap, c.cai, 'Onça'],
          [c.pap, c.cai, 'Onça'],
          [c.zlel],
          [c.zlel],
          [c.ceb, c.san, c.mon], # mônica só em pensamento
          [c.ceb, c.san, c.mon],
          [c.hum],
          [c.hum],
          [c.hum],
          [c.hum],
          [c.hum],
          [c.hum, 'Salva-vidas'],
          [c.hum],
          [c.hum, 'Tritão 1'],
          [c.hum, c.fat(), c.child(), 'Tritão 1', 'Tritão 2', 'Tritão 3'],
          [c.pen, c.alm, c.zvam]] # tirinha final

c.atend(reset = True)
c.mot(reset = True)
c.fat(reset = True)
c.fig(reset = True)
c.child(reset = True)
c.comic_book = 'gibi 4'

# %%
pages4 = [[c.cas, c.ceb, c.mon, 'Duende', 'Múmia'], # capa
          [c.mon], # introdução
          [c.mon],
          [c.mon],
          [c.mon, 'Duende'], # 19 crianças, 2 mães e 2 pais
          [c.mon, 'Duende', c.mmon],
          [c.mon, 'Duende', c.mmon],
          [c.mon, 'Duende', c.mmon, c.child(), c.child()],
          ['Duende', c.atend()], # mais 11 crianças, 3 mães e 2 pais
          ['Duende', c.atend(n = 1), c.mon, c.mmon, c.fat(), c.child(), c.atend()],
          [c.mon, c.mmon, 'Duende'],
          ['Duende', c.atend(), c.atend(), c.child(), c.child()],
          ['Duende', c.mon],
          ['Duende', c.mon, c.child(), c.child()],
          ['Duende', c.mon, c.child(), c.ceb, c.cas],
          ['Duende', c.mon, c.ceb, c.cas],
          ['Duende', c.child(), c.ceb, c.cas],
          ['Duende', c.mon, c.atend(), c.ceb, c.cas],
          ['Duende', c.mon, c.child(), c.child(), c.ceb, c.cas],
          ['Duende', c.mon, c.ceb, c.cas],
          ['Duende', c.mon, c.ceb, c.cas],
          ['Duende', 'Duende 2', 'Duende 3', 'Duende 4'],
          ['Duende', 'Duende 2', 'Duende 3', 'Duende 4', 'Duende 5', 'Papai Noel'],
          ['Duende', 'Duende 2', 'Duende 3', 'Duende 4', 'Duende 5', 'Duende 6', 'Duende 7', 'Papai Noel'],
          ['Duende', 'Duende 2', 'Duende 3', 'Duende 4', 'Duende 5', 'Papai Noel'],
          ['Duende', 'Duende 2', 'Duende 3', 'Papai Noel'],
          ['Papai Noel', 'Rena 1', 'Rena 2', 'Rena 3', 'Duende', c.mon, c.ceb, c.cas],
          [c.cas],
          [c.cas, 'São Paulo', 'Anjinho'],
          [c.ceb, c.cas, c.mon],
          [c.min],
          [c.min, c.mag],
          [c.min, c.mag],
          [c.min, c.mag],
          [c.min, c.mag, c.mmag],
          [c.tv, c.mtv],
          [c.tv, c.mtv, c.blo], # a mãe tá só em voz
          [c.tv, c.mtv, c.blo],
          [c.tv, c.mtv, c.blo],
          [c.tv, c.mtv, c.blo],
          [c.tv, c.mtv, c.blo],
          [c.tv, c.mtv, c.blo],
          [c.tv, c.blo],
          [c.tv, c.mtv, c.blo],
          [c.cas, c.ceb, 'Enxame de abelhas'],
          [c.chi, 'Galo', 'Cachorro', 'Lesma'],
          [c.chi, 'Tartaruga', 'Morcego', 'Formigas', 'Coruja'],
          [c.chi, 'Coelho', 'Macacos', 'Preguiça', 'Cavalo'], # dois macacos
          ['Pato', c.chi, 'Mula', 'Porco', 'Gatos'], # 3 filhotes de gato e a gata
          ['Bodes', c.chi, c.ros, 'Pássaros'], # dois bodes e dois pássaros
          [c.pit, 'Gronk'],
          [c.pit, 'Gronk'],
          [c.pit, 'Gronk'],
          [c.mon, c.ceb],
          [c.mon, c.ceb],
          [c.mon, c.ceb],
          [c.mon, c.ceb],
          [c.ceb]] # louco também? cebolinha vira o louco no último quadrinho

c.atend(reset = True)
c.mot(reset = True)
c.fat(reset = True)
c.fig(reset = True)
c.child(reset = True)
c.comic_book = 'gibi 5'

# %%
pages5 = [['Homem Invisível', 'Mulher Invisível', c.cra, c.zcav, c.fra, c.lob, c.zvam, c.mum, c.pen],
          [c.pen],
          [c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child()],
          [c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), 
           c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child()],
          [c.child(), c.child(), c.child(), c.child(), c.child()],
          [c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.fig()],
          [c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child()],
          [c.mag, c.atend(), c.atend()], # e mais 10 crianças...
          [c.pen, c.cra],
          ['Funcionário Parque', c.pen],
          [c.zvam, c.mum, c.fra, c.lob, c.cra, c.pen, c.zcav, 'Camisa 1', 'Camisa 2', 'Camisa 3', 'Vestido', 'Lixo'],
          [c.zvam, c.mum, c.fra, c.lob, c.cra, c.pen, c.zcav, 'Vestido', c.alm, 'Toalha', 'Lixo', 'Fantasminha'],
          [c.zvam, c.fra, c.cra, c.pen, 'Vestido', c.alm, 'Lixo', 'Fantasminha'],
          [c.zvam, c.lob, c.cra, c.pen, 'Vestido', c.alm, 'Toalha', 'Camisa 1', 'Camisa 2', 'Camisa 3', 'Fantasminha'],
          [c.fra, c.lob, c.cra, c.zcav, c.pen, 'Vestido', c.alm, 'Toalha', 'Lixo', 'Camisa 1', 'Camisa 2', 'Camisa 3', 'Fantasminha'],
          ['Guarda', c.zcav, c.pen, 'Vestido', 'Toalha', 'Lixo', 'Camisa 1', 'Camisa 2', 'Camisa 3'],
          [c.cas],
          [c.cas, c.mcas],
          [c.mon, c.mar, c.bid], # Bidu só em fala
          [c.mon, c.mar, c.bid],
          [c.mon, c.mar, c.floq],
          [c.mon, c.mar, c.moca, 'Labrador', 'Cachorro Branco', 'Pitbull'],
          [c.mon, c.mar, c.ceb, c.san],
          [c.mceb, c.ceb, 'Anjinho', 'Anjinho 2', 'Anjinho 3', 'Anjinho 4', 'Anjinho 5'],
          [c.chi, 'Galo'],
          [c.chi, 'Galo'],
          [c.mau, 'Desenhista 1', 'Desenhista 2', 'Desenhista 3', 'Desenhista 4'], # no fundo tem uns caras na praia também
          [c.mau, 'Desenhista 1', 'Desenhista 2', 'Desenhista 3', 'Desenhista 4', 'Tina'],
          ['Rita Najura', 'Jotalhão', 'Formiga'],
          [c.dud, c.cas, 'Anjinho', c.franj, c.mon], # passatempos
          [c.mon, c.mag, c.cas, c.ceb, c.bid, c.xav, c.pen], # correio
          [c.mon, c.mag, c.chi, c.nim, c.cas], # tem três meninas que não conheço (correio)
          [c.lob, c.pen, c.fra],
          [c.lob, c.pen, c.fra],
          [c.lob, c.pen, c.fra],
          [c.lob, c.pen, c.fra, 'Doutor'],
          [c.lob, c.pen, c.fra, 'Doutor'],
          [c.lob, c.pen, c.fra],
          [c.lob, c.pen, c.fra],
          [c.ceb, c.floq],
          [c.ceb, c.floq],
          [c.ast],
          [c.ast],
          [c.ast],
          [], # só aparece a nave do astronauta
          [c.ast],
          [c.ast],
          [c.ast, 'Astronauta do Futuro'],
          [c.ast, 'Astronauta do Futuro'],
          [c.ast, c.mast, c.past],
          [c.zcav, 'Cachorro'],
          [c.ceb, c.san],
          [c.ceb, c.san, c.moca],
          [c.ceb, c.san, c.moca],
          [c.ceb, c.san, c.moca, c.mon],
          [c.ceb, c.san, c.moca, c.mon],
          [c.ceb, c.san, c.moca, c.mon],
          [c.ceb, c.san, c.moca, c.mon],
          [c.ceb, c.san, c.moca, c.mon],
          [c.ceb, c.san, c.moca, c.mon, c.cas],
          [c.pen, c.alm]] # tirinha do final

c.atend(reset = True)
c.mot(reset = True)
c.fat(reset = True)
c.fig(reset = True)
c.child(reset = True)
c.comic_book = 'gibi 6'

# %%
pages6 = [[c.san, c.ceb, c.cas, c.mon], # capa
          [c.san, c.ceb, c.cas, c.mon], # introdução
          [c.child(), c.child(), c.mceb, c.ceb, c.cas, 'Tartaruga', 'Lebre', c.fig(), c.fig()], # figurantes na sombra
          [c.ceb, c.cas, c.fig(), c.fig(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(),
           c.fig(), c.fig(), c.fig(), c.fig(), c.fig(), c.fig(), c.fig(), c.fig(), c.fig(), c.san],
           # só uma criança aparece inteira, o resto é sombra/pés
          [c.san, c.ceb, c.cas, c.mon, c.child(), c.child(), c.fig(), c.fig(), c.fig(), c.fig()],
           # fig e crianças só na sombra
          [c.san, c.ceb, c.cas, c.mon],
          [c.san, c.ceb, c.cas, c.mon], # página 9
          [c.mon, c.ceb, c.cas, 'Cérebro do Cebolinha'], # são 5 bonequinhos similares ao cebolinha
          [c.ceb, c.cas],
          [c.ceb, c.cas, c.san],
          [c.ceb, c.cas, c.san],
          [c.ceb, c.cas, c.san],
          [c.ceb, c.cas, c.san, c.child(), c.child()],
          [c.ceb, c.cas, c.san, c.child(), c.atend(), c.mon],
          [c.ceb, c.cas, c.san],
          [c.ceb, c.cas, c.child()],
          [c.ceb, c.cas],
          [c.ceb, c.cas],
          [c.ceb, c.cas, 'Moça achados e perdidos'],
          [c.ceb, c.cas, 'Moça achados e perdidos', c.mon],
          [c.ceb, c.cas, 'Moça achados e perdidos', c.mon],
          [c.ceb, c.cas, 'Cérebro do Cebolinha', c.mon],
          ['Moça achados e perdidos', c.ceb, c.cas, c.mon, c.mceb, c.mot(), c.child(), c.fig()], # fig era só sombra
          [c.san, c.ceb, c.mon, c.mag],
          [c.mag, c.mon, c.san],
          [c.mag, c.mon, c.san, c.cas],
          [c.mon],
          [c.mon, c.san, c.ceb],
          [c.mon, c.san, c.ceb, c.cas],
          [c.ceb, c.mag, c.cas, c.mon, c.san], # passatempos
          [c.ceb, c.mag, c.cas, c.mon, c.san, c.bid], # correio
          [c.ceb, 'Bolinha amarela estranha'], # correio
          [c.ceb, c.mon, c.mceb, c.san],
          [c.ceb, c.mon, c.mceb, c.san],
          [c.pen, 'Cupido', c.fra, 'Moça'],
          [c.pen, c.zvam, c.lob, 'Morcego', 'Cachorro', 'Cupido'],
           # morcego é quem se apaixonou pelo zé vampir e cachorro pelo lobi
          [c.fra, 'Moça', c.lob, 'Cachorro', c.zvam, 'Morcego', c.pen, 'Cupido', c.alm],
          [c.chi, c.nho],
          [c.rol, 'Verinha'],
          [c.rol, 'Verinha'],
          [c.rol, 'Verinha', c.fig()],
          [c.luc],
          [c.luc, c.ceb, c.cas],
          [c.luc, c.ceb, c.cas, c.mon, c.san],
          [c.luc, c.mon, c.san, c.mag, c.den],
          [c.luc, c.mon, c.ceb, c.cas, c.franj],
          [c.luc],
          [c.luc, c.min, c.bid, c.mag, c.mon, c.san, c.xav, c.cas, c.pxav, 'Banda', c.child(), 'Elefante',
           'Sequestradores'],
          [c.luc],
          [c.luc, c.ceb, c.cas, 'Médico'],
          [c.chi, c.ros, c.prof],
          [c.chi, c.pad, c.mchi, 'Dentista'],
          [c.mon, c.ceb],
          [c.mon, c.ceb, c.cas],
          [c.mon, c.ceb, c.cas],
          [c.mon, c.ceb, 'Fabinho'], # fabinho só em caricatura num balão de fala
          [c.mon, c.ceb, 'Fabinho'], # e agora ao vivo
          [c.mon, c.ceb, c.child(), c.mot(), c.fig()],
          [c.mon, c.ceb, c.mar],
          [c.mon, c.ceb, c.mar],
          [c.pen, c.zcav]] # tirinha final

c.atend(reset = True)
c.mot(reset = True)
c.fat(reset = True)
c.fig(reset = True)
c.child(reset = True)
c.comic_book = 'gibi 7'

# %%
pages7 = [[c.mon, c.mar, c.ceb, c.cas, c.xav, c.nim, c.con, c.hum, c.jer],
          [c.den, c.mon, c.carfru, c.den, c.mag],
          [c.mar, c.mon, c.mag],
          [c.mar, c.mon, c.mag],
          [c.mon, c.mag, c.child(), c.child(), c.child(), c.child()], # as crianças tem apenas a sombra
          [c.mar, c.mon, c.mag, c.child(), c.child(), c.child(), c.child()], # as crianças tem apenas a sombra
          [c.mar, c.mon],
          [c.mon, c.mar, c.ceb, c.cas, c.child(), c.child(), c.child(), c.child(), c.child(), c.child()],
           # três crianças são só sombra
          [c.cas, c.ceb, c.mon, c.mar],
          [c.cas, c.ceb, c.mar, c.mag, c.mon, c.nim, c.xav, c.hum],
          [c.cas, c.ceb, c.mar, c.mag, c.mon, c.nim, c.xav, c.hum, c.den, c.carfru],
          [c.cas, c.ceb, c.mar, c.mag, c.mon, c.nim, c.xav, c.hum, c.den, c.carfru],
          [c.cas, c.ceb, c.mag, c.mon, c.nim, c.xav, c.hum, c.carfru],
          [c.cas, c.ceb, c.mar, c.mag, c.mon, c.nim, c.xav, c.hum, c.den, c.carfru],
          [c.ceb, c.mar, c.mag, c.mon, c.nim, c.den, c.carfru, c.child(), c.child(), c.child(), c.child(), c.child(),
           c.child(), c.child(), c.child()], # duas crianças só em sombra
          [c.mon, c.mag, c.den, c.carfru, c.child(), c.child(), c.child(), c.child(), c.child(), c.child()],
          [c.mon, c.mag, c.den, c.carfru, c.mar, c.mau, c.child(), c.child(), c.child(), c.child(), c.child(), c.child(),
           c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child()],
          [c.mon, c.mag, c.den, c.carfru, c.mar, c.mau, c.ali, 
           c.child(add = -1), c.child(add = -2), c.child(add = -3),
           c.child(add = -4), c.child(add = -5), c.child(add = -6), c.child(add = -7), c.child(add = -8),
           c.child(add = -9), c.child(add = -10), c.child(add = -11), c.child(add = -12), c.child(add = -13),
           c.child(add = -14), c.child(add = -15), c.child(add = -16), c.child(add = -17), c.child(add = -18)],
           # 6 dessas são só sombras (coloquei repetidos por que daria muita criança num só gibi)
          [c.cas, c.ceb],
          [c.mag, c.ceb, c.mon, c.san, c.mmag],
          [c.mon, c.san, c.ceb, c.cas, c.mcas, c.zlui],
          [c.cas, c.mon, c.ceb],
          [c.cas, c.mag, c.mau, c.ali],
          [c.paj],
          [c.paj, c.cac, 'Índia', 'Índio'],
          [c.paj, c.cac, 'Índia', 'Índio', c.pap],
          [c.cas],
          [c.mon, c.mag, c.ceb],
          [c.dud, c.xav, c.spa, c.anj, 'Anjo 1', 'Anjo 2', 'Anjo 3'],
          [c.jot, c.mon, c.ceb, c.cas, c.mag], # passatempo
          [c.mon, c.mag, c.ceb, c.cas, c.bid, c.gen], # correio
          [c.mon, c.quin, c.nim, c.cas], # correio
          ['Equilibrista', c.mon, c.mag, c.fig(), c.fig(), c.fig(), c.fig(), 'Palhaço 1', 'Palhaço 2'],
          ['Homem Bala', c.mon, c.mag, c.fig(add = -1), c.fig(add = -2), c.fig(add = -3), c.fig(add = -4), 'Palhaço 3'],
          ['Mulher 1', 'Mulher 2', 'Mulher 3'],
          ['Mulher 3', 'Mulher 4', c.pen, 'Fantasma do Sultão'],
          [c.mar],
          [c.mar, 'Gato'],
          [c.mar, 'Pitbull'],
          [c.mar, c.luc, c.mon, c.den, c.mag],
          [c.ceb, c.mag, c.mon],
          [c.ceb, c.mon, c.mag, 'Alienígenas'], # 6 aliens
          [c.ast],
          [c.ast, 'Policial Alien'],
          [c.ast, 'Policial Alien'],
          [c.ast, 'Policial Alien', 'Computador do Astronauta', 'Senhorita Argh', 'Alien 1', 'Alien 2'],
          [c.ast, 'Senhorita Argh', 'Alien 1', 'Alien 2'],
          [c.ast, 'Alien 1', 'Alien 2', 'Alien 3', 'Senhorita Argh', c.fig(), c.fig()],
          [c.ast, 'Alien 1', 'Alien 2', 'Senhorita Argh'],
          [c.ast, 'Alien 1', 'Alien 2', 'Senhorita Argh'],
          [c.ast, 'Alien 1', 'Alien 2', 'Senhorita Argh'],
          [c.ast, 'Alien 1', 'Alien 2', 'Senhorita Argh', c.mast],
          [c.mon, c.mmon, c.ceb, c.mceb, c.mag, c.mmag, c.cas, c.mcas],
          [c.ceb],
          [c.ceb, c.pceb],
          [c.ceb, c.pceb],
          [c.ceb, c.pceb],
          [c.ceb, c.pceb],
          [c.ceb, c.pceb],
          [c.mau, c.mar],
          [c.ceb, c.lou]] # tirinha do final

c.atend(reset = True)
c.mot(reset = True)
c.fat(reset = True)
c.fig(reset = True)
c.child(reset = True)
c.comic_book = 'gibi 8'

# %%
comic_books = [pages1,
               pages2,
               pages3,
               pages4,
               pages5,
               pages6,
               pages7,
               pages8,
               pages9,
               pages10,
               pages11,
               pages12,
               pages13,
               pages14,
               pages15,
               pages16,
               pages17,
               pages18,
               pages19,
               pages20,
               pages21,
               pages22,
               pages23,
               pages24,
               pages25]

# %%
for i in range(len(comic_books)):
    if comic_books[i] != []:
        try:
            cb = TM()
            for page in comic_books[i]:
                cb.insert(page)

            cb.pack(f'Data\comic book {i + 1}.csv')
        except:
            pass
