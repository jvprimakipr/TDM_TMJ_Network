# %%
import sys

# importando classes
sys.path.insert(0, 'Functions')
from class_TM import TM

# voltando para o diretório principal
sys.path.insert(0, '\..')

# %%
cb1 = TM()
pages = [['Caricatura do Maurício', 'Bruxa Viviane', 'Mônica', 'Cebolinha', 'Magali'], # capa
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Cebolinha', 'Magali', 'Sansão'], # introdução
         ['Bruxa Viviane', 'Gato da Bruxa Viviane'], # gato = bóris
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Atendente 1 - Parque da Mônica', 'Atendente 2 - Parque da Mônica'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Atendente 1 - Parque da Mônica'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Atendente 1 - Parque da Mônica'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Cebolinha', 'Cascão'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Cebolinha', 'Cascão'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Cebolinha', 'Cascão'],
         ['Bruxa Viviane', 'Mônica', 'Cebolinha', 'Cascão'],
         ['Bruxa Viviane', 'Mônica', 'Cebolinha', 'Cascão'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Cebolinha', 'Cascão'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Magali', 'Menino com cabelo laranja e camisa roxa'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Magali'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Magali', 'Figurante 1 - Lanchonete', 'Atendente 3 - Lanchonete'],
         ['Bruxa Viviane', 'Magali', 'Atendente 4 - Ce-bolinhas'],
         ['Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão', 'Atendente 4 - Ce-bolinhas'],
         ['Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão'],
         ['Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão'],
         ['Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão'], # dinossauros do horácio também?
         ['Bruxa Viviane', 'Magali'], # dinossauros do horácio também?
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Magali'],
         ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão'],
         ['Piteco'],
         ['Piteco'],
         ['Piteco', 'Dinossauro verde'],
         ['Piteco', 'Dinossauro verde'],
         ['Penadinho'],
         ['Penadinho', 'Gato laranja'],
         ['Cebolinha', 'Floquinho'],
         ['Cebolinha', 'Floquinho'],
         ['Dudu', 'Mãe do Dudu'],
         ['Dudu', 'Lactos Kid'], # caixinha de leite vilã
         ['Dudu', 'Lactos Kid', 'Milhus', 'Ervilhus'], # lata de milho e ervilha vilãs
         ['Dudu', 'Lactos Kid', 'Milhus', 'Ervilhus', 'Macarrônios', 'Povo Feijônico', 'Monstro Q.I. Jo'], # macarrão, feijões e queijo, todos vilões
         ['Dudu', 'Mãe do Dudu', 'Lactos Kid', 'Milhus', 'Ervilhus', 'Povo Feijônico'],
         ['Bidu', 'Franjinha', 'Cebolinha'],
         ['Bidu', 'Cebolinha', 'Mônica', 'Cascão'],
         ['Astronauta', 'Monstro Verde Grande', 'Monstro Rosa'],
         ['Astronauta', 'Monstro Rosa', 'Monstro Verde Pequeno'],
         ['Zé Lelé', 'Figurante 1 - Parque', 'Figurante 2 - Parque', 'Atendente 5 - Parque', 'Galinha do Zé Lelé', 'Pintinho'],
         ['Zé Lelé', 'Galinha do Zé Lelé', 'Atendente 5 - Parque', 'Atendente 6 - Parque', 'Criança no Brinquedo - 1',
          'Criança no Brinquedo - 2', 'Criança no Brinquedo - 3', 'Criança no Brinquedo - 4', 'Criança no Brinquedo - 5',
          'Criança no Brinquedo - 6', 'Criança no Brinquedo - 7', 'Criança no Brinquedo - 8', 'Criança no Brinquedo - 9',
          'Criança no Brinquedo - 10', 'Criança no Brinquedo - 11', 'Criança no Brinquedo - 12'],
         ['Zé Lelé', 'Galinha do Zé Lelé', 'Mãe do Zé Lelé', 'Criança no Brinquedo - 13', 'Criança no Brinquedo - 14',
          'Criança no Brinquedo - 15', 'Criança no Brinquedo - 16'],
         ['Lobi', 'Cachorro 1', 'Cachorro 2', 'Peixe', 'Pássaro', 'Menino de cabelo laranja e camisa verde'],
         ['Lobi', 'Cachorro 1', 'Cachorro 2', 'Menino com skate', 'Mulher na rua'],
         ['Mônica', 'Franjinha', 'Bidu'],
         ['Mônica', 'Magali', 'Mingau', 'Cebolinha', 'Floquinho'],
         ['Tina', 'Pipa'],
         ['Tina', 'Pipa', 'Serginho'],
         ['Tina', 'Pipa', 'Serginho'],
         ['Tina', 'Pipa'],
         ['Tina', 'Pipa', 'Serginho'],
         ['Tina', 'Pipa', 'Serginho'],
         ['Zé Vampir', 'Muminho', 'Penadinho', 'Cranicola']] # última página (tirinha)
for page in pages:
    cb1.insert(page)
    
cb1.pack('Data\comic book 1.csv')
cb1.data
# Out:
#                     Character 1            Character 2  \
# Page
# Page 1   Caricatura do Maurício          Bruxa Viviane
# Page 2            Bruxa Viviane  Gato da Bruxa Viviane
# Page 3            Bruxa Viviane  Gato da Bruxa Viviane
# Page 4            Bruxa Viviane  Gato da Bruxa Viviane
# Page 5            Bruxa Viviane  Gato da Bruxa Viviane
# Page 6            Bruxa Viviane  Gato da Bruxa Viviane
# Page 7            Bruxa Viviane  Gato da Bruxa Viviane
# Page 8            Bruxa Viviane  Gato da Bruxa Viviane
# Page 9            Bruxa Viviane  Gato da Bruxa Viviane
# Page 10           Bruxa Viviane  Gato da Bruxa Viviane
# Page 11           Bruxa Viviane  Gato da Bruxa Viviane
# Page 12           Bruxa Viviane  Gato da Bruxa Viviane
# Page 13           Bruxa Viviane                 Mônica
# Page 14           Bruxa Viviane                 Mônica
# Page 15           Bruxa Viviane  Gato da Bruxa Viviane
# Page 16           Bruxa Viviane  Gato da Bruxa Viviane
# ...

# %%
# só para mostrar o método mesmo
# isso retorna a lista de personagens
# cb1.characters

# quantidade de personagens
cb1.n_characters
# Out:
# 72

# %%
pages1 = [['Bruxa Viviane', 'Mônica', 'Cebolinha', 'Magali'], # capa
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Cebolinha', 'Magali', 'Sansão'], # introdução
          ['Bruxa Viviane', 'Gato da Bruxa Viviane'], # gato = bóris
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Atendente 1 - Parque da Mônica', 'Atendente 2 - Parque da Mônica'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Atendente 1 - Parque da Mônica'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Atendente 1 - Parque da Mônica'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Cebolinha', 'Cascão'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Cebolinha', 'Cascão'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Cebolinha', 'Cascão'],
          ['Bruxa Viviane', 'Mônica', 'Cebolinha', 'Cascão'],
          ['Bruxa Viviane', 'Mônica', 'Cebolinha', 'Cascão'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Cebolinha', 'Cascão'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Magali', 'Menino com cabelo laranja e camisa roxa'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Magali'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Magali', 'Figurante 1 - Lanchonete', 'Atendente 3 - Lanchonete'],
          ['Bruxa Viviane', 'Magali', 'Atendente 4 - Ce-bolinhas'],
          ['Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão', 'Atendente 4 - Ce-bolinhas'],
          ['Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão'],
          ['Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão'],
          ['Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão'], # dinossauros do horácio também?
          ['Bruxa Viviane', 'Magali'], # dinossauros do horácio também?
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Magali'],
          ['Bruxa Viviane', 'Gato da Bruxa Viviane', 'Mônica', 'Magali', 'Cebolinha', 'Cascão'],
          ['Piteco'],
          ['Piteco'],
          ['Piteco', 'Dinossauro verde'],
          ['Piteco', 'Dinossauro verde'],
          ['Penadinho'],
          ['Penadinho', 'Gato laranja'],
          ['Cebolinha', 'Floquinho'],
          ['Cebolinha', 'Floquinho'],
          ['Dudu', 'Mãe do Dudu'],
          ['Dudu', 'Lactos Kid'], # caixinha de leite vilã
          ['Dudu', 'Lactos Kid', 'Milhus', 'Ervilhus'], # lata de milho e ervilha vilãs
          ['Dudu', 'Lactos Kid', 'Milhus', 'Ervilhus', 'Macarrônios', 'Povo Feijônico', 'Monstro Q.I. Jo'], # macarrão, feijões e queijo, todos vilões
          ['Dudu', 'Mãe do Dudu', 'Lactos Kid', 'Milhus', 'Ervilhus', 'Povo Feijônico'],
          ['Bidu', 'Franjinha', 'Cebolinha'],
          ['Bidu', 'Cebolinha', 'Mônica', 'Cascão'],
          ['Astronauta', 'Monstro Verde Grande', 'Monstro Rosa'],
          ['Astronauta', 'Monstro Rosa', 'Monstro Verde Pequeno'],
          ['Zé Lelé', 'Figurante 1 - Parque', 'Figurante 2 - Parque', 'Atendente 5 - Parque', 'Galinha do Zé Lelé', 'Pintinho'],
          ['Zé Lelé', 'Galinha do Zé Lelé', 'Atendente 5 - Parque', 'Atendente 6 - Parque', 'Criança no Brinquedo - 1',
           'Criança no Brinquedo - 2', 'Criança no Brinquedo - 3', 'Criança no Brinquedo - 4', 'Criança no Brinquedo - 5',
           'Criança no Brinquedo - 6', 'Criança no Brinquedo - 7', 'Criança no Brinquedo - 8', 'Criança no Brinquedo - 9',
           'Criança no Brinquedo - 10', 'Criança no Brinquedo - 11', 'Criança no Brinquedo - 12'],
          ['Zé Lelé', 'Galinha do Zé Lelé', 'Mãe do Zé Lelé', 'Criança no Brinquedo - 13', 'Criança no Brinquedo - 14',
           'Criança no Brinquedo - 15', 'Criança no Brinquedo - 16'],
          ['Lobi', 'Cachorro 1', 'Cachorro 2', 'Peixe', 'Pássaro', 'Menino de cabelo laranja e camisa verde'],
          ['Lobi', 'Cachorro 1', 'Cachorro 2', 'Menino com skate', 'Mulher na rua'],
          ['Mônica', 'Franjinha', 'Bidu'],
          ['Mônica', 'Magali', 'Mingau', 'Cebolinha', 'Floquinho'],
          ['Tina', 'Pipa'],
          ['Tina', 'Pipa', 'Serginho'],
          ['Tina', 'Pipa', 'Serginho'],
          ['Tina', 'Pipa'],
          ['Tina', 'Pipa', 'Serginho'],
          ['Tina', 'Pipa', 'Serginho'],
          ['Zé Vampir', 'Muminho', 'Penadinho', 'Cranicola']] # última página (tirinha)

# %%
pages2 = [['Magali', 'Dud Van Winkle', 'Figurante Capa'], # capa (Dud parece o Dudu)
          ['Magali', 'Dudu'],
          ['Magali', 'Dudu'],
          ['Magali', 'Dudu'],
          ['Magali', 'Dudu', 'Figurante 1'],
          ['Mulher - História', 'Homem - História', 'Boi 1', 'Boi 2', 'Cachorro', 'Galo',
           'Galinha', 'Dudu', 'Dud Van Winkle'],
          ['Magali', 'Dudu', 'Dud Van Winkle', 'Vovó - História'],
          ['Dud Van Winkle', 'Vaca', 'Galinha', 'Tartaruga', 'Caracol'],
          ['Magali', 'Dudu', 'Dud Van Winkle'],
          ['Dud Van Winkle'],
          ['Dudu', 'Magali', 'Construtor 1', 'Construtor 2', 'Construtor 3'],
          ['Construtor 4', 'Construtor 5', 'Criança', 'Mãe'],
          ['Maurício', 'Dud Van Winkle', 'Figurante 2'],
          ['Maurício', 'Dud Van Winkle'],
          ['Dud Van Winkle', 'Dudu', 'Magali'],
          ['Dudu', 'Magali', 'Penadinho'], # penadinho era num brinquedo
          ['Dudu', 'Magali', 'Maurício', 'Dud Van Winkle'],
          ['Cascão'],
          ['Cascão'],
          ['Cebolinha', 'Mônica', 'Magali', 'Sansão'],
          ['Cascão', 'Mônica', 'Magali', 'Sansão'],
          ['Mônica', 'Magali', 'Sansão', 'Xaveco'],
          ['Monicão', 'Mingau'],
          ['Mônica', 'Magali', 'Sansão', 'Monicão', 'Mingau', 'Chovinista', 'Floquinho', 'Cachorro Verde Aleatório'],
          ['Franjinha', 'Bidu', 'Monicão', 'Mingau', 'Chovinista', 'Floquinho', 'Cachorro Verde Aleatório'],
          ['Lobi', 'Zé Vampir'],
          ['Zé Vampir', 'Penadinho', 'Frank', 'Muminho'],
          ['Mônica', 'Magali', 'Carminha FruFru', 'Vendedor de Picolé'],
          ['Mônica', 'Cebolinha', 'Titi', 'Super Homem', 'Cascão'],
          ['Piteco', 'Homem das Cavernas 1', 'Homem das Cavernas 2'],
          ['Piteco', 'Homem das Cavernas 1', 'Homem das Cavernas 2'],
          ['Piteco', 'Homem das Cavernas 1', 'Homem das Cavernas 2'],
          ['Piteco', 'Dente de Sabre', 'Dinossauro Amarelo'],
          ['Piteco', 'Homem das Cavernas 3', 'Homem das Cavernas 4'],
          ['Dudu'],
          ['Dudu'],
          ['Dudu', 'Mãe do Dudu'],
          ['Magali', 'Franjinha'],
          ['Magali', 'Franjinha'],
          ['Magali', 'Franjinha'],
          ['Franjinha'],
          ['Magali', 'Franjinha'],
          ['Magali', 'Franjinha'],
          ['Magali', 'Franjinha'],
          ['Magali', 'Mãe da Magali'], # acho que ela quem chama a magali para casa (não aparece, só o balão de voz)
          ['Magali', 'Anjo da Guarda da Magali'],
          ['Bidu', 'Pedra'], # a pedra fala!!!
          ['Bidu', 'Pedra', 'Manfredo'],
          ['Bidu', 'Manfredo', 'Desenhista 1', 'Desenhista 2', 'Desenhista 3'],
          ['Bidu', 'Manfredo', 'Pedra'],
          ['Bidu', 'Pedra', 'Manfredo'],
          ['Bidu', 'Manfredo', 'Pedra'],
          ['Bidu', 'Manfredo', 'Pedra'],
          ['Bidu', 'Manfredo', 'Pedra'],
          ['Bidu', 'Manfredo', 'Pedra'],
          ['Bidu', 'Manfredo', 'Desenhista 1', 'Desenhista 2', 'Desenhista 3'],
          ['Bidu', 'Manfredo', 'Desenhista 1', 'Desenhista 2', 'Desenhista 3', 'Pedra']]

# %%
pages3 = [['Seu Cebola', 'Cebolinha', 'Mônica', 'Cascão'], # capa
          ['Seu Cebola', 'Cebolinha'], # introdução
          ['Cebolinha', 'Seu Cebola', 'Atendente do Parque 1', 'Atendente do Parque 2',
           'Criança 1', 'Criança 2', 'Criança 3', 'Criança 4'],
          ['Cebolinha', 'Seu Cebola', 'Criança 5', 'Criança 6', 'Criança 7', 'Pai 1'],
          ['Cebolinha', 'Seu Cebola', 'Criança 8', 'Criança 9', 'Criança 10', 'Mãe 1', 'Atendente Lanchonete'],
          ['Cebolinha', 'Seu Cebola', 'Criança 11', 'Criança 12'],
          ['Cebolinha', 'Seu Cebola', 'Criança 12'],
          ['Cebolinha', 'Seu Cebola', 'Criança 12'],
          ['Cebolinha', 'Seu Cebola', 'Atendente Karaokê'],
          ['Cebolinha', 'Seu Cebola', 'Criança 13'],
          ['Cebolinha', 'Seu Cebola', 'Criança 14', 'Criança 15'],
          ['Cebolinha', 'Seu Cebola', 'Criança 14', 'Criança 15'],
          ['Cebolinha', 'Seu Cebola', 'Criança 16', 'Criança 17', 'Criança 18', 'Criança 19', 'Criança 20'],
          ['Cebolinha', 'Seu Cebola', 'Criança 21', 'Criança 22', 'Criança 23'],
          ['Cebolinha', 'Seu Cebola', 'Mãe 2', 'Bebê', 'Pai 2'],
          ['Cebolinha', 'Seu Cebola', 'Bebê', 'Pai 2'],
          ['Cebolinha', 'Seu Cebola', 'Jogador 1', 'Jogador 2', 'Jogador 3',
           'Jogador 4', 'Jogador 5', 'Dona Cebola', 'Pai 2', 'Bebê'],
          ['Cebolinha', 'Seu Cebola'],
          ['Cebolinha', 'Seu Cebola', 'Pai Caramujo', 'Filho Caramujo'],
          ['Mônica', 'Sansão', 'Magali'],
          ['Cebolinha', 'Magali', 'Cascão', 'Xaveco', 'Sorveteiro'],
          ['Cascão', 'Figurante 1', 'Figurante 2', 'Figurante 3'],
          ['Cascão', 'Figurante 4', 'Figurante 5', 'Figurante 6', 'Figurante 7'],
          ['Cascão', 'Mãe do Cascão', 'Caixa do Supermercado'],
          ['Piteco', 'Vartolo', 'Dinossauro Rosa'],
          ['Piteco', 'Vartolo', 'Bolota'],
          ['Piteco', 'Vartolo', 'Homem Tigre 1'],
          ['Homem Tigre 1', 'Piteco', 'Vartolo', 'Bolota', 'Homem das Cavernas 1'],
          ['Piteco', 'Vartolo', 'Bolota', 'Homem Tigre 1', 'Homem Tigre 2', 'Homem Tigre 3'],
          ['Piteco', 'Vartolo', 'Bolota', 'Homem das Cavernas 2', 'Homem das Cavernas 3',
           'Homem das Cavernas 4', 'Homem das Cavernas 5', 'Homem das Cavernas 6'],
          ['Homem Tigre 1', 'Homem Tigre 2', 'Homem Tigre 3', 'Homem Tigre 4', 'Homem Tigre 5', 'Piteco',
           'Bolota', 'Vartolo', 'Homem das Cavernas 1', 'Homem das Cavernas 2', 'Homem das Cavernas 3'],
          ['Zé Vampir', 'Figurante 1'],
          ['Cebolinha', 'Cascão' 'Do Contra'], # passatempo
          ['Cebolinha', 'Mônica', 'Cascão', 'Magali', 'Maria Cebolinha', 'Xaveco', 'Bidu'], # correio
          ['Cascão', 'Cebolinha', 'Mônica', 'Magali'], # correio de novo
          ['Penadinho', 'Figurante 8', 'Figurante 9', 'Figurante 10'],
          ['Penadinho'],
          ['Penadinho', 'Frank'],
          ['Penadinho', 'Frank', 'Zé Vampir', 'Muminho', 'Esqueleto'],
          ['Penadinho', 'Frank', 'Zé Vampir', 'Muminho', 'Esqueleto', 'Lobi',
           'Dona Morte', 'Alminha', 'Fantasma 1', 'Fantasma 2'],
          ['Mônica', 'Cebolinha', 'Cascão', 'Sansão'],
          ['Mônica', 'Cebolinha', 'Cascão', 'Sansão'],
          ['Papa-Capim', 'Caiapopó'],
          ['Papa-Capim', 'Caiapopó', 'Onça'],
          ['Papa-Capim', 'Caiapopó', 'Onça'],
          ['Papa-Capim', 'Caiapopó', 'Onça'],
          ['Zé Lelé'],
          ['Zé Lelé'],
          ['Cebolinha', 'Sansão', 'Mônica'], # mônica só em pensamento
          ['Cebolinha', 'Sansão', 'Mônica'],
          ['Humberto'],
          ['Humberto'],
          ['Humberto'],
          ['Humberto'],
          ['Humberto'],
          ['Humberto', 'Salva-vidas'],
          ['Humberto'],
          ['Humberto', 'Tritão 1'],
          ['Humberto', 'Pai', 'Criança', 'Tritão 1', 'Tritão 2', 'Tritão 3'],
          ['Penadinho', 'Alminha', 'Zé Vampir']] # tirinha final

# %%
pages4 = [[],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          []]

# %%
pages5 = [[],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          []]

# %%
pages6 = [[],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          []]

# %%
pages7 = [[],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          []]

# %%
pages8 = [[],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          []]

# %%
pages9 = [[],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          []]

# %%
pages10 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages11 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages12 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages13 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages14 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages15 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages16 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages17 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages18 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages19 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages20 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages21 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages22 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages23 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages24 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages25 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
comic_books = [pages1,
               pages2,
               pages3,
               pages4,
               pages5,
               pages6,
               pages7,
               pages8,
               pages9,
               pages10,
               pages11,
               pages12,
               pages13,
               pages14,
               pages15,
               pages16,
               pages17,
               pages18,
               pages19,
               pages20,
               pages21,
               pages22,
               pages23,
               pages24,
               pages25]

# %%
for i in range(len(comic_books)):
    try:
        cb = TM()
        for page in comic_books[i]:
            cb.insert(page)

        cb.pack(f'Data\comic book {i + 1}.csv')
    except:
        pass
