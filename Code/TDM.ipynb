# %%
import sys

# importando classes
sys.path.insert(0, 'Functions')
from class_TM import TM
from class_characters import characters

# voltando para o diretório principal
sys.path.insert(0, '\..')
c = characters()

# %%
pages = [[c.viv, c.mon, c.ceb, c.mag], # capa
         [c.viv, c.bor, c.mon, c.ceb, c.mag, c.san], # introdução
         [c.viv, c.bor], # gato = bóris
         [c.viv, c.bor, c.mon, c.mag, c.ceb, c.cas],
         [c.viv, c.bor],
         [c.viv, c.bor],
         [c.viv, c.bor, c.atend(), c.atend()],
         [c.viv, c.bor, c.atend(n = 1)],
         [c.viv, c.bor, c.atend(n = 1)],
         [c.viv, c.bor, c.ceb, c.cas],
         [c.viv, c.bor, c.mon, c.ceb, c.cas],
         [c.viv, c.bor, c.mon, c.ceb, c.cas],
         [c.viv, c.mon, c.ceb, c.cas],
         [c.viv, c.mon, c.ceb, c.cas],
         [c.viv, c.bor, c.mon, c.ceb, c.cas],
         [c.viv, c.bor, c.mag, c.child()],
         [c.viv, c.bor, c.mag],
         [c.viv, c.bor, c.mag, c.fig(), c.atend()],
         [c.viv, c.mag, c.atend()],
         [c.viv, c.mon, c.mag, c.ceb, c.cas, c.atend(n = 4)],
         [c.viv, c.mon, c.mag, c.ceb, c.cas],
         [c.viv, c.mon, c.mag, c.ceb, c.cas],
         [c.viv, c.mon, c.mag, c.ceb, c.cas], # dinossauros do horácio também?
         [c.viv, c.mag], # dinossauros do horácio também?
         [c.viv, c.bor, c.mag],
         [c.viv, c.bor, c.mon, c.mag, c.ceb, c.cas],
         [c.pit],
         [c.pit],
         [c.pit, 'Dinossauro verde'],
         [c.pit, 'Dinossauro verde'],
         [c.pen],
         [c.pen, 'Gato laranja'],
         [c.ceb, c.floq],
         [c.ceb, c.floq],
         [c.dud, c.mdud],
         [c.dud, 'Lactos Kid'], # caixinha de leite vilã
         [c.dud, 'Lactos Kid', 'Milhus', 'Ervilhus'], # lata de milho e ervilha vilãs
         [c.dud, 'Lactos Kid', 'Milhus', 'Ervilhus', 'Macarrônios', 'Povo Feijônico', 'Monstro Q.I. Jo'], # macarrão, feijões e queijo, todos vilões
         [c.dud, c.mdud, 'Lactos Kid', 'Milhus', 'Ervilhus', 'Povo Feijônico'],
         [c.bid, c.franj, c.ceb],
         [c.bid, c.ceb, c.mon, c.cas],
         [c.ast, 'Monstro Verde Grande', 'Monstro Rosa'],
         [c.ast, 'Monstro Rosa', 'Monstro Verde Pequeno'],
         [c.lel, c.fig(), c.fig(), c.atend(), 'Galinha do Zé Lelé', 'Pintinho'],
         [c.lel, 'Galinha do Zé Lelé', c.atend(n = 5), c.atend(), c.child(), c.child(), c.child(), c.child(), c.child(),
          c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child()],
         [c.lel, 'Galinha do Zé Lelé', c.mlel, c.child(), c.child(), c.child(), c.child()],
         [c.lob, 'Cachorro 1', 'Cachorro 2', 'Peixe', 'Pássaro', 'Menino de cabelo laranja e camisa verde'],
         [c.lob, 'Cachorro 1', 'Cachorro 2', c.child(), c.fig()],
         [c.mon, c.franj, c.bid],
         [c.mon, c.mag, c.min, c.ceb, c.floq],
         [c.tin, c.pip],
         [c.tin, c.pip, c.ser],
         [c.tin, c.pip, c.ser],
         [c.tin, c.pip],
         [c.tin, c.pip, c.ser],
         [c.tin, c.pip, c.ser],
         [c.vam, c.mum, c.pen, c.cra]] # última página (tirinha)

cb1 = TM()
for page in pages:
    cb1.insert(page)
    
cb1.pack('Data\comic book 1.csv')
cb1.data
# Out:
#            Character 1           Character 2            Character 3  \
# Page
# Page 1   Bruxa Viviane                Mônica              Cebolinha
# Page 2   Bruxa Viviane                 Bóris                 Mônica
# Page 3   Bruxa Viviane                 Bóris
# Page 4   Bruxa Viviane                 Bóris                 Mônica
# Page 5   Bruxa Viviane                 Bóris
# Page 6   Bruxa Viviane                 Bóris
# Page 7   Bruxa Viviane                 Bóris            Atendente 1
# Page 8   Bruxa Viviane                 Bóris            Atendente 1
# Page 9   Bruxa Viviane                 Bóris            Atendente 1
# Page 10  Bruxa Viviane                 Bóris              Cebolinha
# Page 11  Bruxa Viviane                 Bóris                 Mônica
# Page 12  Bruxa Viviane                 Bóris                 Mônica
# Page 13  Bruxa Viviane                Mônica              Cebolinha
# Page 14  Bruxa Viviane                Mônica              Cebolinha
# ...

# %%
# só para mostrar o método mesmo
# isso retorna a lista de personagens
# cb1.characters

# quantidade de personagens
cb1.n_characters
# Out:
# 71

# %%
pages1 = [[c.viv, c.mon, c.ceb, c.mag], # capa
          [c.viv, c.bor, c.mon, c.ceb, c.mag, c.san], # introdução
          [c.viv, c.bor], # gato = bóris
          [c.viv, c.bor, c.mon, c.mag, c.ceb, c.cas],
          [c.viv, c.bor],
          [c.viv, c.bor],
          [c.viv, c.bor, c.atend(), c.atend()],
          [c.viv, c.bor, c.atend(n = 1)],
          [c.viv, c.bor, c.atend(n = 1)],
          [c.viv, c.bor, c.ceb, c.cas],
          [c.viv, c.bor, c.mon, c.ceb, c.cas],
          [c.viv, c.bor, c.mon, c.ceb, c.cas],
          [c.viv, c.mon, c.ceb, c.cas],
          [c.viv, c.mon, c.ceb, c.cas],
          [c.viv, c.bor, c.mon, c.ceb, c.cas],
          [c.viv, c.bor, c.mag, c.child()],
          [c.viv, c.bor, c.mag],
          [c.viv, c.bor, c.mag, c.fig(), c.atend()],
          [c.viv, c.mag, c.atend()],
          [c.viv, c.mon, c.mag, c.ceb, c.cas, c.atend(n = 4)],
          [c.viv, c.mon, c.mag, c.ceb, c.cas],
          [c.viv, c.mon, c.mag, c.ceb, c.cas],
          [c.viv, c.mon, c.mag, c.ceb, c.cas], # dinossauros do horácio também?
          [c.viv, c.mag], # dinossauros do horácio também?
          [c.viv, c.bor, c.mag],
          [c.viv, c.bor, c.mon, c.mag, c.ceb, c.cas],
          [c.pit],
          [c.pit],
          [c.pit, 'Dinossauro verde'],
          [c.pit, 'Dinossauro verde'],
          [c.pen],
          [c.pen, 'Gato laranja'],
          [c.ceb, c.floq],
          [c.ceb, c.floq],
          [c.dud, c.mdud],
          [c.dud, 'Lactos Kid'], # caixinha de leite vilã
          [c.dud, 'Lactos Kid', 'Milhus', 'Ervilhus'], # lata de milho e ervilha vilãs
          [c.dud, 'Lactos Kid', 'Milhus', 'Ervilhus', 'Macarrônios', 'Povo Feijônico', 'Monstro Q.I. Jo'], # macarrão, feijões e queijo, todos vilões
          [c.dud, c.mdud, 'Lactos Kid', 'Milhus', 'Ervilhus', 'Povo Feijônico'],
          [c.bid, c.franj, c.ceb],
          [c.bid, c.ceb, c.mon, c.cas],
          [c.ast, 'Monstro Verde Grande', 'Monstro Rosa'],
          [c.ast, 'Monstro Rosa', 'Monstro Verde Pequeno'],
          [c.lel, c.fig(), c.fig(), c.atend(), 'Galinha do Zé Lelé', 'Pintinho'],
          [c.lel, 'Galinha do Zé Lelé', c.atend(n = 5), c.atend(), c.child(), c.child(), c.child(), c.child(), c.child(),
           c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child()],
          [c.lel, 'Galinha do Zé Lelé', c.mlel, c.child(), c.child(), c.child(), c.child()],
          [c.lob, 'Cachorro 1', 'Cachorro 2', 'Peixe', 'Pássaro', 'Menino de cabelo laranja e camisa verde'],
          [c.lob, 'Cachorro 1', 'Cachorro 2', c.child(), c.fig()],
          [c.mon, c.franj, c.bid],
          [c.mon, c.mag, c.min, c.ceb, c.floq],
          [c.tin, c.pip],
          [c.tin, c.pip, c.ser],
          [c.tin, c.pip, c.ser],
          [c.tin, c.pip],
          [c.tin, c.pip, c.ser],
          [c.tin, c.pip, c.ser],
          [c.vam, c.mum, c.pen, c.cra]] # última página (tirinha)

# %%
pages2 = [['Magali', 'Dud Van Winkle', 'Figurante Capa'], # capa (Dud parece o Dudu)
          ['Magali', 'Dudu'],
          ['Magali', 'Dudu'],
          ['Magali', 'Dudu'],
          ['Magali', 'Dudu', 'Figurante 1'],
          ['Mulher - História', 'Homem - História', 'Boi 1', 'Boi 2', 'Cachorro', 'Galo',
           'Galinha', 'Dudu', 'Dud Van Winkle'],
          ['Magali', 'Dudu', 'Dud Van Winkle', 'Vovó - História'],
          ['Dud Van Winkle', 'Vaca', 'Galinha', 'Tartaruga', 'Caracol'],
          ['Magali', 'Dudu', 'Dud Van Winkle'],
          ['Dud Van Winkle'],
          ['Dudu', 'Magali', 'Construtor 1', 'Construtor 2', 'Construtor 3'],
          ['Construtor 4', 'Construtor 5', 'Criança', 'Mãe'],
          ['Maurício', 'Dud Van Winkle', 'Figurante 2'],
          ['Maurício', 'Dud Van Winkle'],
          ['Dud Van Winkle', 'Dudu', 'Magali'],
          ['Dudu', 'Magali', 'Penadinho'], # penadinho era num brinquedo
          ['Dudu', 'Magali', 'Maurício', 'Dud Van Winkle'],
          ['Cascão'],
          ['Cascão'],
          ['Cebolinha', 'Mônica', 'Magali', 'Sansão'],
          ['Cascão', 'Mônica', 'Magali', 'Sansão'],
          ['Mônica', 'Magali', 'Sansão', 'Xaveco'],
          ['Monicão', 'Mingau'],
          ['Mônica', 'Magali', 'Sansão', 'Monicão', 'Mingau', 'Chovinista', 'Floquinho', 'Cachorro Verde Aleatório'],
          ['Franjinha', 'Bidu', 'Monicão', 'Mingau', 'Chovinista', 'Floquinho', 'Cachorro Verde Aleatório'],
          ['Lobi', 'Zé Vampir'],
          ['Zé Vampir', 'Penadinho', 'Frank', 'Muminho'],
          ['Mônica', 'Magali', 'Marina', 'Vendedor de Picolé'],
          ['Mônica', 'Cebolinha', 'Titi', 'Super Homem', 'Cascão'],
          ['Piteco', 'Homem das Cavernas 1', 'Homem das Cavernas 2'],
          ['Piteco', 'Homem das Cavernas 1', 'Homem das Cavernas 2'],
          ['Piteco', 'Homem das Cavernas 1', 'Homem das Cavernas 2'],
          ['Piteco', 'Dente de Sabre', 'Dinossauro Amarelo'],
          ['Piteco', 'Homem das Cavernas 3', 'Homem das Cavernas 4'],
          ['Dudu'],
          ['Dudu'],
          ['Dudu', 'Mãe do Dudu'],
          ['Magali', 'Franjinha'],
          ['Magali', 'Franjinha'],
          ['Magali', 'Franjinha'],
          ['Franjinha'],
          ['Magali', 'Franjinha'],
          ['Magali', 'Franjinha'],
          ['Magali', 'Franjinha'],
          ['Magali', 'Mãe da Magali'], # acho que ela quem chama a magali para casa (não aparece, só o balão de voz)
          ['Magali', 'Anjo da Guarda da Magali'],
          ['Bidu', 'Pedra'], # a pedra fala!!!
          ['Bidu', 'Pedra', 'Manfredo'],
          ['Bidu', 'Manfredo', 'Desenhista 1', 'Desenhista 2', 'Desenhista 3'],
          ['Bidu', 'Manfredo', 'Pedra'],
          ['Bidu', 'Pedra', 'Manfredo'],
          ['Bidu', 'Manfredo', 'Pedra'],
          ['Bidu', 'Manfredo', 'Pedra'],
          ['Bidu', 'Manfredo', 'Pedra'],
          ['Bidu', 'Manfredo', 'Pedra'],
          ['Bidu', 'Manfredo', 'Desenhista 1', 'Desenhista 2', 'Desenhista 3'],
          ['Bidu', 'Manfredo', 'Desenhista 1', 'Desenhista 2', 'Desenhista 3', 'Pedra']]

# %%
pages3 = [['Seu Cebola', 'Cebolinha', 'Mônica', 'Cascão'], # capa
          ['Seu Cebola', 'Cebolinha'], # introdução
          ['Cebolinha', 'Seu Cebola', 'Atendente do Parque 1', 'Atendente do Parque 2',
           'Criança 1', 'Criança 2', 'Criança 3', 'Criança 4'],
          ['Cebolinha', 'Seu Cebola', 'Criança 5', 'Criança 6', 'Criança 7', 'Pai 1'],
          ['Cebolinha', 'Seu Cebola', 'Criança 8', 'Criança 9', 'Criança 10', 'Mãe 1', 'Atendente Lanchonete'],
          ['Cebolinha', 'Seu Cebola', 'Criança 11', 'Criança 12'],
          ['Cebolinha', 'Seu Cebola', 'Criança 12'],
          ['Cebolinha', 'Seu Cebola', 'Criança 12'],
          ['Cebolinha', 'Seu Cebola', 'Atendente Karaokê'],
          ['Cebolinha', 'Seu Cebola', 'Criança 13'],
          ['Cebolinha', 'Seu Cebola', 'Criança 14', 'Criança 15'],
          ['Cebolinha', 'Seu Cebola', 'Criança 14', 'Criança 15'],
          ['Cebolinha', 'Seu Cebola', 'Criança 16', 'Criança 17', 'Criança 18', 'Criança 19', 'Criança 20'],
          ['Cebolinha', 'Seu Cebola', 'Criança 21', 'Criança 22', 'Criança 23'],
          ['Cebolinha', 'Seu Cebola', 'Mãe 2', 'Bebê', 'Pai 2'],
          ['Cebolinha', 'Seu Cebola', 'Bebê', 'Pai 2'],
          ['Cebolinha', 'Seu Cebola', 'Jogador 1', 'Jogador 2', 'Jogador 3',
           'Jogador 4', 'Jogador 5', 'Dona Cebola', 'Pai 2', 'Bebê'],
          ['Cebolinha', 'Seu Cebola'],
          ['Cebolinha', 'Seu Cebola', 'Pai Caramujo', 'Filho Caramujo'],
          ['Mônica', 'Sansão', 'Magali'],
          ['Cebolinha', 'Magali', 'Cascão', 'Xaveco', 'Sorveteiro'],
          ['Cascão', 'Figurante 1', 'Figurante 2', 'Figurante 3'],
          ['Cascão', 'Figurante 4', 'Figurante 5', 'Figurante 6', 'Figurante 7'],
          ['Cascão', 'Mãe do Cascão', 'Caixa do Supermercado'],
          ['Piteco', 'Vartolo', 'Dinossauro Rosa'],
          ['Piteco', 'Vartolo', 'Bolota'],
          ['Piteco', 'Vartolo', 'Homem Tigre 1'],
          ['Homem Tigre 1', 'Piteco', 'Vartolo', 'Bolota', 'Homem das Cavernas 1'],
          ['Piteco', 'Vartolo', 'Bolota', 'Homem Tigre 1', 'Homem Tigre 2', 'Homem Tigre 3'],
          ['Piteco', 'Vartolo', 'Bolota', 'Homem das Cavernas 2', 'Homem das Cavernas 3',
           'Homem das Cavernas 4', 'Homem das Cavernas 5', 'Homem das Cavernas 6'],
          ['Homem Tigre 1', 'Homem Tigre 2', 'Homem Tigre 3', 'Homem Tigre 4', 'Homem Tigre 5', 'Piteco',
           'Bolota', 'Vartolo', 'Homem das Cavernas 1', 'Homem das Cavernas 2', 'Homem das Cavernas 3'],
          ['Zé Vampir', 'Figurante 1'],
          ['Cebolinha', 'Cascão' 'Do Contra'], # passatempo
          ['Cebolinha', 'Mônica', 'Cascão', 'Magali', 'Maria Cebolinha', 'Xaveco', 'Bidu'], # correio
          ['Cascão', 'Cebolinha', 'Mônica', 'Magali'], # correio de novo
          ['Penadinho', 'Figurante 8', 'Figurante 9', 'Figurante 10'],
          ['Penadinho'],
          ['Penadinho', 'Frank'],
          ['Penadinho', 'Frank', 'Zé Vampir', 'Muminho', 'Esqueleto'],
          ['Penadinho', 'Frank', 'Zé Vampir', 'Muminho', 'Esqueleto', 'Lobi',
           'Dona Morte', 'Alminha', 'Fantasma 1', 'Fantasma 2'],
          ['Mônica', 'Cebolinha', 'Cascão', 'Sansão'],
          ['Mônica', 'Cebolinha', 'Cascão', 'Sansão'],
          ['Papa-Capim', 'Caiapopó'],
          ['Papa-Capim', 'Caiapopó', 'Onça'],
          ['Papa-Capim', 'Caiapopó', 'Onça'],
          ['Papa-Capim', 'Caiapopó', 'Onça'],
          ['Zé Lelé'],
          ['Zé Lelé'],
          ['Cebolinha', 'Sansão', 'Mônica'], # mônica só em pensamento
          ['Cebolinha', 'Sansão', 'Mônica'],
          ['Humberto'],
          ['Humberto'],
          ['Humberto'],
          ['Humberto'],
          ['Humberto'],
          ['Humberto', 'Salva-vidas'],
          ['Humberto'],
          ['Humberto', 'Tritão 1'],
          ['Humberto', 'Pai', 'Criança', 'Tritão 1', 'Tritão 2', 'Tritão 3'],
          ['Penadinho', 'Alminha', 'Zé Vampir']] # tirinha final

# %%
pages4 = [['Cascão', 'Cebolinha', 'Mônica', 'Duende', 'Múmia'], # capa
          ['Mônica'], # introdução
          ['Mônica'],
          ['Mônica'],
          ['Mônica', 'Duende'], # 19 crianças, 2 mães e 2 pais
          ['Mônica', 'Duende', 'Mãe da Mônica'],
          ['Mônica', 'Duende', 'Mãe da Mônica'],
          ['Mônica', 'Duende', 'Mãe da Mônica', 'Criança 1', 'Criança 2'],
          ['Duende', 'Atendente - Entrada'], # mais 11 crianças, 3 mães e 2 pais
          ['Duende', 'Atendente - Entrada', 'Mônica', 'Mãe da Mônica', 'Pai 1', 'Criança 3', 'Atendente - Caixa'],
          ['Mônica', 'Mãe da Mônica', 'Duende'],
          ['Duende', 'Atendente - Loja 1', 'Atendente - Loja 2', 'Criança 4', 'Criança 5'],
          ['Duende', 'Mônica'],
          ['Duende', 'Mônica', 'Criança 6', 'Criança 7'],
          ['Duende', 'Mônica', 'Criança 8', 'Cebolinha', 'Cascão'],
          ['Duende', 'Mônica', 'Cebolinha', 'Cascão'],
          ['Duende', 'Criança 9', 'Cebolinha', 'Cascão'],
          ['Duende', 'Mônica', 'Atendente - Lanchonete', 'Cebolinha', 'Cascão'],
          ['Duende', 'Mônica', 'Criança 10', 'Criança 11', 'Cebolinha', 'Cascão'],
          ['Duende', 'Mônica', 'Cebolinha', 'Cascão'],
          ['Duende', 'Mônica', 'Cebolinha', 'Cascão'],
          ['Duende', 'Duende 2', 'Duende 3', 'Duende 4'],
          ['Duende', 'Duende 2', 'Duende 3', 'Duende 4', 'Duende 5', 'Papai Noel'],
          ['Duende', 'Duende 2', 'Duende 3', 'Duende 4', 'Duende 5', 'Duende 6', 'Duende 7', 'Papai Noel'],
          ['Duende', 'Duende 2', 'Duende 3', 'Duende 4', 'Duende 5', 'Papai Noel'],
          ['Duende', 'Duende 2', 'Duende 3', 'Papai Noel'],
          ['Papai Noel', 'Rena 1', 'Rena 2', 'Rena 3', 'Duende', 'Mônica', 'Cebolinha', 'Cascão'],
          ['Cascão'],
          ['Cascão', 'São Paulo', 'Anjinho'],
          ['Cebolinha', 'Cascão', 'Mônica'],
          ['Mingau'],
          ['Mingau', 'Magali'],
          ['Mingau', 'Magali'],
          ['Mingau', 'Magali'],
          ['Mingau', 'Magali', 'Mãe da Magali'],
          ['Teveluisão', 'Mãe do Teveluisão'],
          ['Teveluisão', 'Mãe do Teveluisão', 'Bloguinho'], # a mãe tá só em voz
          ['Teveluisão', 'Mãe do Teveluisão', 'Bloguinho'],
          ['Teveluisão', 'Mãe do Teveluisão', 'Bloguinho'],
          ['Teveluisão', 'Mãe do Teveluisão', 'Bloguinho'],
          ['Teveluisão', 'Mãe do Teveluisão', 'Bloguinho'],
          ['Teveluisão', 'Mãe do Teveluisão', 'Bloguinho'],
          ['Teveluisão', 'Bloguinho'],
          ['Teveluisão', 'Mãe do Teveluisão', 'Bloguinho'],
          ['Cascão', 'Cebolinha', 'Enxame de abelhas'],
          ['Chico Bento', 'Galo', 'Cachorro', 'Lesma'],
          ['Chico Bento', 'Tartaruga', 'Morcego', 'Formigas', 'Coruja'],
          ['Chico Bento', 'Coelho', 'Macacos', 'Preguiça', 'Cavalo'], # dois macacos
          ['Pato', 'Chico Bento', 'Mula', 'Porco', 'Gatos'], # 3 filhotes de gato e a gata
          ['Bodes', 'Chico Bento', 'Rosinha', 'Pássaros'], # dois bodes e dois pássaros
          ['Piteco', 'Gronk'],
          ['Piteco', 'Gronk'],
          ['Piteco', 'Gronk'],
          ['Mônica', 'Cebolinha'],
          ['Mônica', 'Cebolinha'],
          ['Mônica', 'Cebolinha'],
          ['Mônica', 'Cebolinha'],
          ['Cebolinha']] # louco também? cebolinha vira o louco no último quadrinho

# %%
pages5 = [['Homem Invisível', 'Mulher Invisível', 'Cranícola', 'Esqueleto', 'Frank', 'Lobi', 'Zé Vampir', 'Muminho', 'Penadinho'],
          ['Penadinho'],
          ['Criança 1', 'Criança 2', 'Criança 3', 'Criança 4', 'Criança 5', 'Criança 6', 'Criança 7', 'Criança 8'],
          [f'Criança {i}' for i in range(9, 9 + 17)],
          [f'Criança {i}' for i in range(9 + 17, 9 + 17 + 5)],
          [f'Criança {i}' for i in range(9 + 17 + 5, 9 + 17 + 5 + 6)],
          [f'Criança {i}' for i in range(9 + 17 + 5 + 6, 9 + 17 + 5 + 6 + 10)],
          ['Magali', 'Atendente - Lanchonete 1', 'Atendente - Lanchonete 2'], # e mais 10 crianças...
          ['Penadinho', 'Cranícola'],
          ['Funcionário Parque', 'Penadinho'],
          ['Zé Vampir', 'Muminho', 'Frank', 'Lobi', 'Cranícola', 'Penadinho', 'Esqueleto', 'Camisa 1', 'Camisa 2', 'Camisa 3', 'Vestido', 'Lixo'],
          ['Zé Vampir', 'Muminho', 'Frank', 'Lobi', 'Cranícola', 'Penadinho', 'Esqueleto', 'Vestido', 'Alminha', 'Toalha', 'Lixo', 'Fantasminha'],
          ['Zé Vampir', 'Frank', 'Cranícola', 'Penadinho', 'Vestido', 'Alminha', 'Lixo', 'Fantasminha'],
          ['Zé Vampir', 'Lobi', 'Cranícola', 'Penadinho', 'Vestido', 'Alminha', 'Toalha', 'Camisa 1', 'Camisa 2', 'Camisa 3', 'Fantasminha'],
          ['Frank', 'Lobi', 'Cranícola', 'Esqueleto', 'Penadinho', 'Vestido', 'Alminha', 'Toalha', 'Lixo', 'Camisa 1', 'Camisa 2', 'Camisa 3', 'Fantasminha'],
          ['Guarda', 'Esqueleto', 'Penadinho', 'Vestido', 'Toalha', 'Lixo', 'Camisa 1', 'Camisa 2', 'Camisa 3'],
          ['Cascão'],
          ['Cascão', 'Mãe do Cascão'],
          ['Mônica', 'Marina', 'Bidu'], # Bidu só em fala
          ['Mônica', 'Marina', 'Bidu'],
          ['Mônica', 'Marina', 'Floquinho'],
          ['Mônica', 'Marina', 'Monicão', 'Labrador', 'Cachorro Branco', 'Pitbull'],
          ['Mônica', 'Marina', 'Cebolinha', 'Sansão'],
          ['Dona Cebola', 'Cebolinha', 'Anjinho', 'Anjinho 2', 'Anjinho 3', 'Anjinho 4', 'Anjinho 5'],
          ['Chico Bento', 'Galo'],
          ['Chico Bento', 'Galo'],
          ['Maurício', 'Desenhista 1', 'Desenhista 2', 'Desenhista 3', 'Desenhista 4'], # no fundo tem uns caras na praia também
          ['Maurício', 'Desenhista 1', 'Desenhista 2', 'Desenhista 3', 'Desenhista 4', 'Tina'],
          ['Rita Najura', 'Jotalhão', 'Formiga'],
          ['Dudu', 'Cascão', 'Anjinho', 'Franjinha', 'Mônica'], # passatempos
          ['Mônica', 'Magali', 'Cascão', 'Cebolinha', 'Bidu', 'Xaveco', 'Penadinho'], # correio
          ['Mônica', 'Magali', 'Chico Bento', 'Nimbus', 'Cascão'], # tem três meninas que não conheço (correio)
          ['Lobi', 'Penadinho', 'Frank'],
          ['Lobi', 'Penadinho', 'Frank'],
          ['Lobi', 'Penadinho', 'Frank'],
          ['Lobi', 'Penadinho', 'Frank', 'Doutor'],
          ['Lobi', 'Penadinho', 'Frank', 'Doutor'],
          ['Lobi', 'Penadinho', 'Frank'],
          ['Lobi', 'Penadinho', 'Frank'],
          ['Cebolinha', 'Floquinho'],
          ['Cebolinha', 'Floquinho'],
          ['Astronauta'],
          ['Astronauta'],
          ['Astronauta'],
          [], # só aparece a nave do astronauta
          ['Astronauta'],
          ['Astronauta'],
          ['Astronauta', 'Astronauta do Futuro'],
          ['Astronauta', 'Astronauta do Futuro'],
          ['Astronauta', 'Mãe do Astronauta', 'Pai do Astronauta'],
          ['Esqueleto', 'Cachorro'],
          ['Cebolinha', 'Sansão'],
          ['Cebolinha', 'Sansão', 'Monicão'],
          ['Cebolinha', 'Sansão', 'Monicão'],
          ['Cebolinha', 'Sansão', 'Monicão', 'Mônica'],
          ['Cebolinha', 'Sansão', 'Monicão', 'Mônica'],
          ['Cebolinha', 'Sansão', 'Monicão', 'Mônica'],
          ['Cebolinha', 'Sansão', 'Monicão', 'Mônica'],
          ['Cebolinha', 'Sansão', 'Monicão', 'Mônica'],
          ['Cebolinha', 'Sansão', 'Monicão', 'Mônica', 'Cascão'],
          ['Penadinho', 'Alminha']] # tirinha do final

pages5[5].append('Figurante 1')

# %%
pages6 = [[c.san, c.ceb, c.cas, c.mon], # capa
          [c.san, c.ceb, c.cas, c.mon], # introdução
          [c.child(), c.child(), c.mceb, c.ceb, c.cas, 'Tartaruga', 'Lebre', c.fig(), c.fig()], # figurantes na sombra
          [c.ceb, c.cas, c.fig(), c.fig(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(), c.child(),
           c.fig(), c.fig(), c.fig(), c.fig(), c.fig(), c.fig(), c.fig(), c.fig(), c.fig(), c.san],
           # só uma criança aparece inteira, o resto é sombra/pés
          [c.san, c.ceb, c.cas, c.mon, c.child(), c.child(), c.fig(), c.fig(), c.fig(), c.fig()],
           # fig e crianças só na sombra
          [c.san, c.ceb, c.cas, c.mon],
          [c.san, c.ceb, c.cas, c.mon], # página 9
          [c.mon, c.ceb, c.cas, 'Cérebro do Cebolinha'], # são 5 bonequinos similares ao cebolinha
          [c.ceb, c.cas],
          [c.ceb, c.cas, c.san],
          [c.ceb, c.cas, c.san],
          [c.ceb, c.cas, c.san],
          [c.ceb, c.cas, c.san, c.child(), c.child()],
          [c.ceb, c.cas, c.san, c.child(), c.atend(), c.mon],
          [c.ceb, c.cas, c.san],
          [c.ceb, c.cas, c.child()],
          [c.ceb, c.cas],
          [c.ceb, c.cas],
          [c.ceb, c.cas, 'Moça achados e perdidos'],
          [c.ceb, c.cas, 'Moça achados e perdidos', c.mon],
          [c.ceb, c.cas, 'Moça achados e perdidos', c.mon],
          [c.ceb, c.cas, 'Cérebro do Cebolinha', c.mon],
          ['Moça achados e perdidos', c.ceb, c.cas, c.mon, c.mceb, c.mot(), c.child(), c.fig()], # fig era só sombra
          [c.san, c.ceb, c.mon, c.mag],
          [c.mag, c.mon, c.san],
          [c.mag, c.mon, c.san, c.cas],
          [c.mon],
          [c.mon, c.san, c.ceb],
          [c.mon, c.san, c.ceb, c.cas],
          [c.ceb, c.mag, c.cas, c.mon, c.san], # passatempos
          [c.ceb, c.mag, c.cas, c.mon, c.san, c.bid], # correio
          [c.ceb, 'Bolinha amarela estranha'], # correio
          [c.ceb, c.mon, c.mceb, c.san],
          [c.ceb, c.mon, c.mceb, c.san],
          [c.pen, 'Cupido', c.fra, 'Moça'],
          [c.pen, c.vam, c.lob, 'Morcego', 'Cachorro', 'Cupido'], # morcego é quem se apaixonou pelo zé vampir e cachorro pelo lobi
          [c.fra, 'Moça', c.lob, 'Cachorro', c.vam, 'Morcego', c.pen, 'Cupido', c.alm],
          [c.chi, c.nho],
          [c.rol, 'Verinha'],
          [c.rol, 'Verinha'],
          [c.rol, 'Verinha', c.fig()],
          [c.luc],
          [c.luc, c.ceb, c.cas],
          [c.luc, c.ceb, c.cas, c.mon, c.san],
          [c.luc, c.mon, c.san, c.mag, c.den],
          [c.luc, c.mon, c.ceb, c.cas, c.franj],
          [c.luc],
          [c.luc, c.min, c.bid, c.mag, c.mon, c.san, c.xav, c.cas, c.pxav, 'Banda', c.child(), 'Elefante', 'Sequestradores'],
          [c.luc],
          [c.luc, c.ceb, c.cas, 'Médico'],
          [c.chi, c.ros, c.pro],
          [c.chi, c.pad, c.mchi, 'Dentista'],
          [c.mon, c.ceb],
          [c.mon, c.ceb, c.cas],
          [c.mon, c.ceb, c.cas],
          [c.mon, c.ceb, 'Fabinho'], # fabinho só em caricatura num balão de fala
          [c.mon, c.ceb, 'Fabinho'], # e agora ao vivo
          [c.mon, c.ceb, c.child(), c.mot(), c.fig()],
          [c.mon, c.ceb, c.mar],
          [c.mon, c.ceb, c.mar],
          [c.pen, c.cav]] # tirinha final

# %%
pages7 = [[],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          []]

# %%
pages8 = [[],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          []]

# %%
pages9 = [[],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          [],
          []]

# %%
pages10 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages11 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages12 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages13 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages14 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages15 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages16 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages17 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages18 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages19 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages20 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages21 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages22 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages23 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages24 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
pages25 = [[],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           [],
           []]

# %%
comic_books = [pages1,
               pages2,
               pages3,
               pages4,
               pages5,
               pages6,
               pages7,
               pages8,
               pages9,
               pages10,
               pages11,
               pages12,
               pages13,
               pages14,
               pages15,
               pages16,
               pages17,
               pages18,
               pages19,
               pages20,
               pages21,
               pages22,
               pages23,
               pages24,
               pages25]

# %%
for i in range(len(comic_books)):
    try:
        cb = TM()
        for page in comic_books[i]:
            cb.insert(page)

        cb.pack(f'Data\comic book {i + 1}.csv')
    except:
        pass
